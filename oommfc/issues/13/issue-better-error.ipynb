# %%
# %matplotlib notebook

# %%
import oommfc as oc
import discretisedfield as df

# %%
#system = oc.System(name="first_notebook")
system = oc.System(name="first_notebook")

# %%
L = 100e-9
d = 10e-9
mesh = oc.Mesh(p1=(0, 0, 0), p2=(L, L, L), cell=(d, d, d))
A = 1e-12
H = (8e6, 0, 0)
system.hamiltonian = oc.Exchange(A=A) + oc.Demag() + oc.Zeeman(H=H)
alpha = 0.2
system.dynamics = oc.Precession(gamma=oc.gamma0) + oc.Damping(alpha=alpha)
system.m = df.Field(mesh, value=(0, 1, 0), norm=8e6)
fig = system.m.plot_slice("z", 50e-9, xsize=4)
# Out:
# <img src="data:image/png;base64,...">

# %%
md = oc.MinDriver()
md.drive(system)
# Out:
# in call: argstr = 'first_notebook/first_notebook.mif'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-06c529479cd5> in <module>()
#       1 md = oc.MinDriver()
# ----> 2 md.drive(system)
#
# /Users/fangohr/git/joommf-dev/oommfc/oommfc/drivers/driver.py in drive(self, system, **kwargs)
#      34
#      35         if "derive" not in kwargs:
# ---> 36             self._update_system(system)
#      37
#      38     def _makedir(self, system):
#
# /Users/fangohr/git/joommf-dev/oommfc/oommfc/drivers/driver.py in _update_system(self, system)
#      65     def _update_system(self, system):
#      66         self._update_m(system)
# ---> 67         self._update_dt(system)
#      68
#      69     def _update_m(self, system):
#
# /Users/fangohr/git/joommf-dev/oommfc/oommfc/drivers/driver.py in _update_dt(self, system)
#      86         dirname = self._filenames(system)["dirname"]
#      87         last_odt_file = max(glob.iglob("{}*.odt".format(dirname)),
# ---> 88                             key=os.path.getctime)
#      89
#      90         # Update system's datatable.
#
# ValueError: max() arg is an empty sequence
